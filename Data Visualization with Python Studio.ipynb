# %% [markdown]
# # Data Visualization with Python Studio
#
# At this point, you should already have connected with the rest of your group to divide up who is going to do what. Use this notebook to create your visualizations.
#
# Below we set up the dataframe with the Goodreads dataset for you. If you run this cell, you may get an error that some lines were skipped. Do not worry about that! For this studio, we want to focus on creating an effective

# %%
# Here is the setup of the dataframe. Feel free to use .info() or .head() to get a better understanding of what is inside the dataframe!

import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib import style

df = pd.read_csv(r"C:\Users\kisor\Launchcode\GitHub\data-viz-with-pythonStudio\books.csv", error_bad_lines=False)

years = []

for y in df['publication_date']:
    date = y.split("/")
    years.append(date[2])

df["year"] = years
print(years)
years.nunique()
# Out:
# ['2006', '2004', '2003', '2004', '2004', '2005', '2005', '2005', '2002', '2004', '2005', '1996', '2004', '2002', '2004', '2001', '2000', '1990', '1993', '1997', '1991', '2012', '2004', '2003', '2002', '2003', '2004', '2005', '2000', '1994', '2001', '2003', '2005', '2005', '2006', '2003', '2004', '2005', '1990', '2006', '2004', '2004', '2006', '2005', '1982', '2006', '1986', '1990', '1999', '1991', '1994', '1994', '1987', '2002', '1991', '2006', '2006', '2003', '1997', '2002', '2004', '2003', '2003', '2004', '2004', '1987', '1987', '1987', '2004', '1984', '2006', '1987', '2002', '1996', '2005', '2004', '2006', '2000', '2005', '2006', '2006', '2004', '2006', '2004', '2005', '2006', '2005', '2005', '2007', '2004', '2002', '2003', '1965', '2003', '2004', '2004', '2006', '1987', '1990', '1998', '1996', '2005', '1995', '2000', '2003', '1991', '1994', '2002', '2002', '1984', '1994', '2006', '2005', '2006', '2004', '2005', '2004', '1990', '2005', '2001', '1996', '1964', '1994', '1994', '1994', '1994', '1994', '1970', '2003', '2004', '1999', '1994', '1986', '1999', '1998', '1998', '1995', '2003', '2011', '2001', '2004', '2005', '2003', '2002', '2006', '1996', '1990', '1955', '2005', '2005', '2002', '1997', '1991', '1988', '1985', '2006', '1991', '2005', '2005', '1998', '2003', '2011', '2005', '2005', '1993', '1998', '1998', '1991', '1989', '1989', '2004', '1994', '1989', '2006', '2005', '1999', '2000', '2004', '1997', '2006', '1985', '1996', '2005', '1990', '1995', '2004', '1990', '1995', '2006', '2005', '2006', '1987', '1987', '1986', '1995', '2006', '1990', '1991', '2007', '1993', '2002', '2002', '2005', '2006', '1990', '2001', '2002', '1998', '2006', '2001', '1994', '2000', '2006', '2004', '2000', '2005', '2006', '1989', '2003', '2004', '1990', '2005', '2006', '2005', '2006', '2004', '1996', '2006', '2005', '1990', '2002', '2004', '2003', '1998', '2006', '1999', '1963', '2005', '1964', '1999', '1996', '1986', '1997', '2006', '2006', '2002', '2004', '2004', '2003', '2006', '2004', '2004', '2005', '1999', '2008', '2003', '2006', '2006', '2004', '2004', '2004', '2005', '2006', '2004', '2006', '2001', '2006', '2002', '2001', '2005', '2004', '2005', '2001', '2000', '2005', '2006', '2000', '2005', '2004', '2002', '2005', '1988', '2006', '2006', '1993', '2006', '2005', '2006', '2005', '2005', '1998', '2005', '2005', '2002', '2002', '2005', '2004', '2009', '2005', '2005', '2005', '2005', '1998', '2003', '2006', '2002', '2005', '2006', '2005', '2005', '2006', '2006', '2005', '2006', '2004', '2005', '2005', '1998', '2005', '2004', '2006', '2005', '2004', '2008', '2005', '2005', '2006', '1976', '2000', '2009', '2005', '2005', '2002', '2006', '2006', '1975', '2006', '1999', '2005', '2003', '2005', '2003', '2005', '1993', '2004', '1990', '1993', '2001', '2006', '2005', '2007', '2006', '2003', '2004', '2006', '2006', '2006', '2006', '2004', '2005', '1999', '2005', '2006', '2006', '2003', '1993', '2005', '2002', '2012', '1998', '2007', '1998', '2002', '1980', '2004', '2005', '2000', '2005', '1992', '2001', '2006', '2001', '2003', '2003', '2002', '2006', '1973', '2003', '2005', '1991', '2019', '2006', '1998', '1999', '2004', '2003', '1954', '1992', '1998', '1970', '1992', '1997', '1987', '1999', '1997', '2004', '1999', '2003', '1999', '2000', '2006', '1998', '1999', '2003', '1999', '2001', '1999', '2006', '1999', '1997', '2002', '1991', '2005', '1994', '1995', '1996', '2004', '2006', '2006', '2000', '2006', '2001', '2000', '2000', '2015', '1919', '1993', '1921', '1998', '1998', '1923', '1989', '1955', '1969', '1968', '2006', '1990', '1992', '2002', '2003', '1994', '2002', '2006', '2001', '2000', '2002', '2004', '2001', '1995', '1990', '1998', '2006', '2002', '1965', '1999', '2002', '2006', '1992', '1969', '1992', '2004', '1984', '1998', '1961', '2004', '1997', '1992', '2004', '2004', '1998', '1996', '2004', '1969', '1996', '2001', '2002', '2000', '2003', '1994', '1953', '1998', '2006', '1958', '2006', '2005', '1984', '1996', '1984', '1998', '1998', ...
# C:\Users\kisor\AppData\Local\Temp\ipykernel_32892\2980997158.py:9: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(r"C:\Users\kisor\Launchcode\GitHub\data-viz-with-pythonStudio\books.csv", error_bad_lines=False)
# b'Skipping line 3350: expected 12 fields, saw 13\nSkipping line 4704: expected 12 fields, saw 13\nSkipping line 5879: expected 12 fields, saw 13\nSkipping line 8981: expected 12 fields, saw 13\n'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32892\2980997158.py in <module>
#      17 df["year"] = years
#      18 print(years)
# ---> 19 years.nunique()
#
# AttributeError: 'list' object has no attribute 'nunique'

# %%
df.head()
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# 1           eng          870        2153167               29221
# 2           eng          352           6333                 244
# 3           eng          435        2339585               36325
# 4           eng         2690          41428                 164
#
#   publication_date        publisher  year
# 0        9/16/2006  Scholastic Inc.  2006
# 1         9/1/2004  Scholastic Inc.  2004
# 2        11/1/2003       Scholastic  2003
# 3         5/1/2004  Scholastic Inc.  2004
# 4        9/13/2004       Scholastic  2004

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11123 entries, 0 to 11122
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              11123 non-null  int64
#  1   title               11123 non-null  object
#  2   authors             11123 non-null  object
#  3   average_rating      11123 non-null  float64
#  4   isbn                11123 non-null  object
#  5   isbn13              11123 non-null  int64
#  6   language_code       11123 non-null  object
#  7     num_pages         11123 non-null  int64
#  8   ratings_count       11123 non-null  int64
#  9   text_reviews_count  11123 non-null  int64
#  10  publication_date    11123 non-null  object
#  11  publisher           11123 non-null  object
#  12  year                11123 non-null  object
# dtypes: float64(1), int64(5), object(7)
# memory usage: 1.1+ MB

# %%
# book_per_year = df.groupby('year')
# book_title = df.groupby("year")
# print(book_title)
total_books = df["title"].count()
total_books
# Out:
# 11123

# %% [markdown]
# With your dataframe set up, time to start creating visualizations!

# %%
# Use your Python skills to create a visualization here.
style.use('ggplot')
# df = df.set_index('years')
# for y in df['publication_date']:
#     date = y.split("/")
#     years.append(date[2])

# df["year"] = years
# year = list(map(str, ("year")))
total_books = df["title"].count()
# total_books
df_group = pd.DataFrame(df.groupby("title")["year"])
plt.title('Number of books published per year',color = 'black')
plt.xticks(color = 'black')
plt.yticks(color = 'black')
plt.xlabel('Year',color = 'black')
plt.ylabel('Number of books',color = 'black')
plt.legend(loc = 'upper left' , title = 'year', fontsize = 12, labelcolor='black')
plt.savefig('bar_grouped.png')

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
style.use('ggplot')
sb.set(rc={"figure.figsize":(25, 12)}) #width=25, #height=4
df_total=df['year'].sort_values().value_counts()
df_total.plot(kind = 'bar', legend = False)
plt.title('Number of Books Published by Year',color = "black")
plt.xticks(color = 'black')
plt.yticks(color = 'black')
plt.xlabel('Year',color = 'black')
plt.ylabel('Number of Books',color = 'black')
plt.savefig('bar_vertical.png')
plt.show()

# %%
df['year','title'].hist(bins=100)
# df.hist(bins=100)
# df.boxplot(column=['year'])

# %%
# Use your Python skills to create a visualization here.
